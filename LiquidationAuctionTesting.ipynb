# %%
import os
import json
import time
from collections import OrderedDict
import unittest
from datetime import datetime
from collections import namedtuple
import portpicker
from pytezos.contract.interface import ContractInterface
from pytezos.operation import MAX_OPERATIONS_TTL
import pytezos

PROJECT_ROOT = os.getcwd()
CHECKER_DIR = os.getenv(
    "CHECKER_DIR", default=os.path.join(PROJECT_ROOT, "checker-e2eTestsHack")
)
os.environ["PATH"] = f"{os.environ['PATH']}:{PROJECT_ROOT}/bin"
WRITE_GAS_COSTS = os.getenv("WRITE_GAS_COSTS")

from checker_client.checker import *


self = namedtuple("SELF", "client")
self.client = pytezos.pytezos.using("http://localhost:18742", key="edsk3RFfvaFaxbHx8BMtEW1rKQcPtDML3LXjNqMNLCzC3wLC1bWbAt")

# %%
print("Deploying the mock oracle.")
oracle = deploy_contract(
    self.client,
    source_file=os.path.join(PROJECT_ROOT, "util/mock_oracle.tz"),
    initial_storage=(self.client.key.public_key_hash(), 1000000),
    ttl=MAX_OPERATIONS_TTL,
)

print("Deploying ctez contract.")
ctez = deploy_ctez(
    self.client,
    ctez_dir=os.path.join(PROJECT_ROOT, "vendor/ctez"),
    ttl=MAX_OPERATIONS_TTL,
)

print("Deploying Checker.")
checker = deploy_checker(
    self.client,
    checker_dir=CHECKER_DIR,
    oracle=oracle.context.address,
    ctez=ctez["fa12_ctez"].context.address,
    ttl=MAX_OPERATIONS_TTL,
)

print("Deployment finished.")
# Out:
# Deploying the mock oracle.
# Deploying ctez contract.
# Deploying ctez contract...
# Done.
# Deploying ctez FA1.2 contract...
# Done.
# Deploying ctez CFMM contract...
# Done.
# Deploying liquidity contract...
# Done.
# Setting liquidity address in CFMM contract...
# Done.
# Setting CFMM amd ctez FA1.2 addresses in ctez contract...
# Done.
# Deploying Checker.
# Deploying the wrapper.
# Checker address: KT1GosH9zvtJwPFwGpwMbznmxxPwUZtu2B5B
# Deploying the TZIP-16 metadata.
# Deploying TZIP-16 metadata: chunk 1 of 8
# Deploying TZIP-16 metadata: chunk 2 of 8
# Deploying TZIP-16 metadata: chunk 3 of 8
# Deploying TZIP-16 metadata: chunk 4 of 8
# Deploying TZIP-16 metadata: chunk 5 of 8
# Deploying TZIP-16 metadata: chunk 6 of 8
# Deploying TZIP-16 metadata: chunk 7 of 8
# Deploying TZIP-16 metadata: chunk 8 of 8
# Deploying: deposit_tez
#   deployed: chunk 0.
# Deploying: activate_burrow
#   deployed: chunk 0.
# Deploying: sell_kit
#   deployed: chunk 0.
# Deploying: set_burrow_delegate
#   deployed: chunk 0.
# Deploying: mint_kit
#   deployed: chunk 0.
# Deploying: receive_price
#   deployed: chunk 0.
# Deploying: cancel_liquidation_slice
#   deployed: chunk 0.
# Deploying: mark_for_liquidation
#   deployed: chunk 0.
#   deployed: chunk 1.
# Deploying: liquidation_auction_claim_win
#   deployed: chunk 0.
# Deploying: remove_liquidity
#   deployed: chunk 0.
# Deploying: touch
#   deployed: chunk 0.
#   deployed: chunk 1.
#   deployed: chunk 2.
#   deployed: chunk 3.
# Deploying: withdraw_tez
#   deployed: chunk 0.
# Deploying: touch_liquidation_slices
#   deployed: chunk 0.
#   deployed: chunk 1.
# Deploying: deactivate_burrow
#   deployed: chunk 0.
# Deploying: burn_kit
#   deployed: chunk 0.
# Deploying: add_liquidity
#   deployed: chunk 0.
# Deploying: update_operators
#   deployed: chunk 0.
# Deploying: buy_kit
#   deployed: chunk 0.
# Deploying: touch_burrow
#   deployed: chunk 0.
# Deploying: receive_slice_from_burrow
#   deployed: chunk 0.
# Deploying: liquidation_auction_place_bid
#   deployed: chunk 0.
# Deploying: create_burrow
#   deployed: chunk 0.
# Sealing.
# Deployment finished.

# %%
def call_endpoint(contract, name, param, amount=0):
    print("Calling", contract.key.public_key_hash(), "/", name, "with", param)
    return inject(
        self.client,
        getattr(contract, name)(param)
        .with_amount(amount)
        .as_transaction()
        .autofill(ttl=MAX_OPERATIONS_TTL)
        .sign(),
    )

def call_bulk(bulks, *, batch_size):
    batches = [
        bulks[i : i + batch_size] for i in range(0, len(bulks), batch_size)
    ]
    times = []
    for batch_no, batch in enumerate(batches, 1):
        print(
            "Sending",
            len(batches),
            "operations as bulk:",
            "Batch",
            batch_no,
            "of",
            len(batches),
        )
        start = time.time()
        inject(
            self.client,
            self.client.bulk(*batch).autofill(ttl=MAX_OPERATIONS_TTL).sign(),
        )
        times.append(time.time() - start)
    print(f"Times: {times}")

# %%
call_bulk(
    [
        checker.create_burrow((0, None)).with_amount(200_000_000),
        checker.mint_kit((0, 80_000_000)),
    ],
    batch_size=10,
)

call_endpoint(
    ctez["ctez"], "create", (1, None, {"any": None}), amount=2_000_000
)
call_endpoint(ctez["ctez"], "mint_or_burn", (1, 100_000))
call_endpoint(ctez["fa12_ctez"], "approve", (checker.context.address, 100_000))

call_endpoint(
    checker,
    "add_liquidity",
    (100_000, 100_000, 5, int(datetime.now().timestamp()) + 20),
)

burrows = list(range(1, 1001))

call_bulk(
    [
        checker.create_burrow((burrow_id, None)).with_amount(100_000_000)
        for burrow_id in burrows
    ],
    batch_size=100,
)

# Mint as much as possible from the burrows. All should be identical, so we just query the
# first burrow and mint that much kit from all of them.
max_mintable_kit = checker.metadata.burrowMaxMintableKit(
    (self.client.key.public_key_hash(), 1)
).storage_view()

call_bulk(
    [checker.mint_kit(burrow_no, max_mintable_kit) for burrow_no in burrows],
    batch_size=100,
)

# Change the index (kits are 100x valuable)
#
# Keep in mind that we're using a patched checker on tests where the protected index
# is much faster to update.
call_endpoint(oracle, "update", 100_000_000)

# Oracle updates lag one touch on checker
call_endpoint(checker, "touch", None)
call_endpoint(checker, "touch", None)
time.sleep(20)
call_endpoint(checker, "touch", None)

# Now burrows should be overburrowed, so we liquidate them all.
#
# This should use the push_back method of the AVL tree.
call_bulk(
    [
        checker.mark_for_liquidation(
            (self.client.key.public_key_hash(), burrow_no)
        )
        for burrow_no in burrows
    ],
    batch_size=40,
)

# This touch starts a liquidation auction
#
# This would use the split method of the AVL tree. However, if the entire queue
# has less tez than the limit, the 'split' method would trivially return the entire
# tree without much effort; so here we should ensure that the liquidation queue has
# more tez than the limit (FIXME).
call_endpoint(checker, "touch", None)

# And we place a bid

ret = checker.metadata.currentLiquidationAuctionMinimumBid().storage_view()
auction_id, minimum_bid = ret["contents"], ret["nat_1"]
# The return value is supposed to be annotated as "auction_id" and "minimum_bid", I
# do not know why we get these names. I think there is an underlying pytezos bug
# that we should reproduce and create a bug upstream.

# TODO: Send another slice to auction and cancel it. Since we have filled up the auction queue above 
# and the current auction is descending, we should be able to reliably cancel the slice.

# Note the auction ptr for later operations
current_auctions_ptr = checker.storage["deployment_state"]["sealed"]["liquidation_auctions"]["current_auction"]()["contents"]

# Place a bid on the current auction
call_endpoint(
    checker, "liquidation_auction_place_bid", (auction_id, minimum_bid)
)
level_after_bid = self.client.shell.head.level()
# Out:
# Sending 1 operations as bulk: Batch 1 of 1
# ---------------------------------------------------------------------------
# MichelsonError                            Traceback (most recent call last)
# <ipython-input-32-c5808a39c9ec> in <module>
# ----> 1 call_bulk(
#       2     [
#       3         checker.create_burrow((0, None)).with_amount(200_000_000),
#       4         checker.mint_kit((0, 80_000_000)),
#       5     ],
#
# <ipython-input-3-6391aab1c276> in call_bulk(bulks, batch_size)
#      28         inject(
#      29             self.client,
# ---> 30             self.client.bulk(*batch).autofill(ttl=MAX_OPERATIONS_TTL).sign(),
#      31         )
#      32         times.append(time.time() - start)
#
# ~/.cache/pypoetry/virtualenvs/checker-0zVS77ph-py3.8/lib/python3.8/site-packages/pytezos/jupyter.py in __call__(self, *args, **kwargs)
#      81
#      82                 def __call__(self, *args, **kwargs):
# ---> 83                     return method(self.class_instance, *args, **kwargs)
#      84
#      85                 def __repr__(self):
#
# ~/.cache/pypoetry/virtualenvs/checker-0zVS77ph-py3.8/lib/python3.8/site-packages/pytezos/operation/group.py in autofill(self, gas_reserve, burn_reserve, counter, ttl, fee, gas_limit, storage_limit, **kwargs)
#     222         opg_with_metadata = opg.run()
#     223         if not OperationResult.is_applied(opg_with_metadata):
# --> 224             raise RpcError.from_errors(OperationResult.errors(opg_with_metadata))
#     225
#     226         extra_size = (32 + 64) // len(opg.contents) + 1  # size of serialized branch and signature
#
# MichelsonError: ({'id': 'proto.009-PsFLoren.michelson_v1.script_rejected',
#   'kind': 'temporary',
#   'location': 42,
#   'with': {'int': '90'}},)

# %%
level_after_bid = self.client.shell.head.level()

# %%
# New stuff to add to tests

# Restore index
#
# Keep in mind that we're using a patched checker on tests where the protected index
# is much faster to update.
call_endpoint(oracle, "update", 1_000_000)

# %%
# Once max_bid_interval_in_blocks blocks have passed, the liquidation auction we 
# bid on should be complete.
slept = 0
while self.client.shell.head.level() < level_after_bid + 20:
    sleep_for = 2
    time.sleep(sleep_for)
    slept += sleep_for
    if slept > 40:
        raise Exception(
            "Chain is growing at a much slower rate than this test expects. "
            "Check the sandbox to ensure that it is healthy and running with the expected configuration.")

# Touch Checker to update auction state. This should move the current auction which we bid on
# to the completed auctions list.
call_endpoint(checker, "touch", None)

# Touch liquidation slices to update slice state and free up our winnings
# TODO: touch slices

# Claim our winnings
# TODO: liquidation_auction_claim_win
# Out:
# Calling tz1aSkwEot3L2kmUvcoxzjMomb9mvBNuzFK6 / touch with None
#   {'kind': 'big_map',
#          'id': '15',
#          'diff': {'action': 'update', 'updates': []}},
#         {'kind': 'big_map',
#          'id': '14',
#          'diff': {'action': 'update', 'updates': []}},
#         {'kind': 'big_map',
#          'id': '13',
#          'diff': {'action': 'update', 'updates': []}},
#         {'kind': 'big_map',
#          'id': '12',
#          'diff': {'action': 'update', 'updates': []}},
#         {'kind': 'big_map',
#          'id': '11',
#          'diff': {'action': 'update', 'updates': []}},
#         {'kind': 'big_map',
#          'id': '10',
#          'diff': {'action': 'update', 'updates': []}}]}},
#      {'kind': 'transaction',
#       'source': 'KT1GosH9zvtJwPFwGpwMbznmxxPwUZtu2B5B',
#       'nonce': 3,
#       'amount': '0',
#       'destination': 'KT1XdEm8gFeh58M2uKbNLtCbJKPXmkoreYZ3',
#       'parameters': {'entrypoint': 'burrowSendSliceToChecker',
#        'value': {'int': '97901000'}},
#       'result': {'status': 'applied',
#        'storage': {'prim': 'Pair',
#         'args': [{'prim': 'Pair',
#           'args': [{'bytes': '0000a26828841890d3f3a2a1d4083839c7a882fe0501'},
#            {'int': '8'}]},
#          {'bytes': '015a3b2eeae8d94760c662a22fc67e08cf4a3afa3f00'}]},
#        'consumed_gas': '36900',
#        'consumed_milligas': '36899034',
#        'storage_size': '495'}},
#      {'kind': 'transaction',
#       'source': 'KT1XdEm8gFeh58M2uKbNLtCbJKPXmkoreYZ3',
#       'nonce': 8,
#       'amount': '97901000',
#       'destination': 'KT1GosH9zvtJwPFwGpwMbznmxxPwUZtu2B5B',
#       'parameters': {'entrypoint': 'receive_slice_from_burrow',
#        'value': {'prim': 'Pair',
#         'args': [{'bytes': '0000a26828841890d3f3a2a1d4083839c7a882fe0501'},
#          {'int': '8'}]}},
#       'result': {'status': 'applied',
#        'storage': {'prim': 'Pair',
#         'args': [{'int': '10'},
#          {'prim': 'Pair',
#           'args': [{'int': '11'},
#            {'prim': 'Left',
#             'args': [[[{'prim': 'Pair',
#                 'args': [{'int': '12'},
#                  {'prim': 'Pair',
#                   'args': [{'prim': 'Pair',
#                     'args': [{'prim': 'Pair',
#                       'args': [{'int': '100001'}, {'int': '126683'}]},
#                      {'prim': 'Pair',
#                       'args': [{'prim': 'Pair',
#                         'args': [{'int': '126655000000'},
#                          {'int': '100001000000'}]},
#                        {'int': '1879'}]}]},
#                    {'int': '100001'}]}]},
#                {'prim': 'Pair',
#                 'args': [{'bytes': '01a3e8b740667b08cb9f59573f6d27ce463aaeef1e00'},
#                  {'bytes': '01a16e75a833f6af685a3e052059cf7a3b8ae302a700'}]},
#                {'int': '13'},
#                {'int': '14'}],
#               {'prim': 'Pair',
#                'args': [{'prim': 'Some', 'args': [{'int': '100000000'}]},
#                 {'prim': 'Pair',
#                  'args': [{'prim': 'Pair',
#                    'args': [{'prim': 'Pair',
#                      'args': [{'prim': 'Pair',
#                        'args': [{'int': '2030'}, {'int': '15'}]},
#                       {'int': '16'}]},
#                     {'prim': 'Pair',
#                      'args': [{'prim': 'Some',
#                        'args': [{'prim': 'Pair',
#                          'args': [{'int': '2013'}, {'int': '2013'}]}]},
#                       {'prim': 'Some',
#                        'args': [{'prim': 'Pair',
#                          'args': [{'int': '2026'},
#                           {'prim': 'Right',
#                            'args': [{'prim': 'Pair',
#                              'args': [{'int': '1000000330829'},
#                               {'int': '1626076745'}]}]}]}]}]}]},
#                   {'int': '1'}]}]},
#               [{'prim': 'Pair',
#                 'args': [{'prim': 'Pair',
#                   'args': [{'int': '18446754502155676277'},
#                    {'int': '43699089742'}]},
#                  {'prim': 'Pair',
#                   'args': [{'int': '3888291585'}, {'int': '1235555'}]}]},
#                {'prim': 'Pair',
#                 'args': [{'int': '18446744624737676076'},
#                  {'int': '100000000'}]},
#                {'int': '1626076749'},
#                {'int': '43671034486'}],
#               {'prim': 'Pair',
#                'args': [{'int': '100000000'},
#                 {'int': '18446750191961542850'}]},
#               {'int': '2067214388118289116594'}]]}]}]},
#        'big_map_diff': [],
#        'balance_updates': [{'kind': 'contract',
#          'contract': 'KT1XdEm8gFeh58M2uKbNLtCbJKPXmkoreYZ3',
#          'change': '-97901000',
#          'origin': 'block'},
#         {'kind': 'contract',
#          'contract': 'KT1GosH9zvtJwPFwGpwMbznmxxPwUZtu2B5B',
#          'change': '97901000',
#          'origin': 'block'}],
#        'consumed_gas': '40249',
#        'consumed_milligas': '40248445',
#        'storage_size': '673441',
#        'lazy_storage_diff': [{'kind': 'big_map',
#          'id': '16',
#          'diff': {'action': 'update', 'updates': []}},
#         {'kind': 'big_map',
#          'id': '15',
#          'diff': {'action': 'update', 'updates': []}},
#         {'kind': 'big_map',
#          'id': '14',
#          'diff': {'action': 'update', 'updates': []}},
#         {'kind': 'big_map',
#          'id': '13',
#          'diff': {'action': 'update', 'updates': []}},
#         {'kind': 'big_map',
#          'id': '12',
#          'diff': {'action': 'update', 'updates': []}},
#         {'kind': 'big_map',
#          'id': '11',
#          'diff': {'action': 'update', 'updates': []}},
#         {'kind': 'big_map',
#          'id': '10',
#          'diff': {'action': 'update', 'updates': []}}]}},
#      {'kind': 'transaction',
#       'source': 'KT1GosH9zvtJwPFwGpwMbznmxxPwUZtu2B5B',
#       'nonce': 2,
#       'amount': '0',
#       'destination': 'KT1AeoW14mnrJhUuBR3WB8hesUU5nueT6DLY',
#       'parameters': {'entrypoint': 'burrowSendSliceToChecker',
#        'value': {'int': '97901000'}},
#       'result': {'status': 'applied',
#        'storage': {'prim': 'Pair',
#         'args': [{'prim': 'Pair',
#           'args': [{'bytes': '0000a26828841890d3f3a2a1d4083839c7a882fe0501'},
#            {'int': '7'}]},
#          {'bytes': '015a3b2eeae8d94760c662a22fc67e08cf4a3afa3f00'}]},
#        'consumed_gas': '36900',
#        'consumed_milligas': '36899034',
#        'storage_size': '495'}},
#      {'kind': 'transaction',
#       'source': 'KT1AeoW14mnrJhUuBR3WB8hesUU5nueT6DLY',
#       'nonce': 9,
#       'amount': '97901000',
#       'destination': 'KT1GosH9zvtJwPFwGpwMbznmxxPwUZtu2B5B',
#       'parameters': {'entrypoint': 'receive_slice_from_burrow',
#        'value': {'prim': 'Pair',
#         'args': [{'bytes': '0000a26828841890d3f3a2a1d4083839c7a882fe0501'},
#          {'int': '7'}]}},
#       'result': {'status': 'applied',
#        'storage': {'prim': 'Pair',
#         'args': [{'int': '10'},
#          {'prim': 'Pair',
#           'args': [{'int': '11'},
#            {'prim': 'Left',
#             'args': [[[{'prim': 'Pair',
#                 'args': [{'int': '12'},
#                  {'prim': 'Pair',
#                   'args': [{'prim': 'Pair',
#                     'args': [{'prim': 'Pair',
#                       'args': [{'int': '100001'}, {'int': '126683'}]},
#                      {'prim': 'Pair',
#                       'args': [{'prim': 'Pair',
#                         'args': [{'int': '126655000000'},
#                          {'int': '100001000000'}]},
#                        {'int': '1879'}]}]},
#                    {'int': '100001'}]}]},
#                {'prim': 'Pair',
#                 'args': [{'bytes': '01a3e8b740667b08cb9f59573f6d27ce463aaeef1e00'},
#                  {'bytes': '01a16e75a833f6af685a3e052059cf7a3b8ae302a700'}]},
#                {'int': '13'},
#                {'int': '14'}],
#               {'prim': 'Pair',
#                'args': [{'prim': 'Some', 'args': [{'int': '100000000'}]},
#                 {'prim': 'Pair',
#                  'args': [{'prim': 'Pair',
#                    'args': [{'prim': 'Pair',
#                      'args': [{'prim': 'Pair',
#                        'args': [{'int': '2030'}, {'int': '15'}]},
#                       {'int': '16'}]},
#                     {'prim': 'Pair',
#                      'args': [{'prim': 'Some',
#                        'args': [{'prim': 'Pair',
#                          'args': [{'int': '2013'}, {'int': '2013'}]}]},
#                       {'prim': 'Some',
#                        'args': [{'prim': 'Pair',
#                          'args': [{'int': '2026'},
#                           {'prim': 'Right',
#                            'args': [{'prim': 'Pair',
#                              'args': [{'int': '1000000330829'},
#                               {'int': '1626076745'}]}]}]}]}]}]},
#                   {'int': '1'}]}]},
#               [{'prim': 'Pair',
#                 'args': [{'prim': 'Pair',
#                   'args': [{'int': '18446754502155676277'},
#                    {'int': '43699089742'}]},
#                  {'prim': 'Pair',
#                   'args': [{'int': '3888291585'}, {'int': '1235555'}]}]},
#                {'prim': 'Pair',
#                 'args': [{'int': '18446744624737676076'},
#                  {'int': '100000000'}]},
#                {'int': '1626076749'},
#                {'int': '43671034486'}],
#               {'prim': 'Pair',
#                'args': [{'int': '100000000'},
#                 {'int': '18446750191961542850'}]},
#               {'int': '2067214388118289116594'}]]}]}]},
#        'big_map_diff': [],
#        'balance_updates': [{'kind': 'contract',
#          'contract': 'KT1AeoW14mnrJhUuBR3WB8hesUU5nueT6DLY',
#          'change': '-97901000',
#          'origin': 'block'},
#         {'kind': 'contract',
#          'contract': 'KT1GosH9zvtJwPFwGpwMbznmxxPwUZtu2B5B',
#          'change': '97901000',
#          'origin': 'block'}],
#        'consumed_gas': '40249',
#        'consumed_milligas': '40248445',
#        'storage_size': '673441',
#        'lazy_storage_diff': [{'kind': 'big_map',
#          'id': '16',
#          'diff': {'action': 'update', 'updates': []}},
#         {'kind': 'big_map',
#          'id': '15',
#          'diff': {'action': 'update', 'updates': []}},
#         {'kind': 'big_map',
#          'id': '14',
#          'diff': {'action': 'update', 'updates': []}},
#         {'kind': 'big_map',
#          'id': '13',
#          'diff': {'action': 'update', 'updates': []}},
#         {'kind': 'big_map',
#          'id': '12',
#          'diff': {'action': 'update', 'updates': []}},
#         {'kind': 'big_map',
#          'id': '11',
#          'diff': {'action': 'update', 'updates': []}},
#         {'kind': 'big_map',
#          'id': '10',
#          'diff': {'action': 'update', 'updates': []}}]}},
#      {'kind': 'transaction',
#       'source': 'KT1GosH9zvtJwPFwGpwMbznmxxPwUZtu2B5B',
#       'nonce': 1,
#       'amount': '0',
#       'destination': 'KT1UpbbE6FUgRczvMiemRj6x4kkqWRXueqTq',
#       'parameters': {'entrypoint': 'burrowSendSliceToChecker',
#        'value': {'int': '97901000'}},
#       'result': {'status': 'applied',
#        'storage': {'prim': 'Pair',
#         'args': [{'prim': 'Pair',
#           'args': [{'bytes': '0000a26828841890d3f3a2a1d4083839c7a882fe0501'},
#            {'int': '6'}]},
#          {'bytes': '015a3b2eeae8d94760c662a22fc67e08cf4a3afa3f00'}]},
#        'consumed_gas': '36900',
#        'consumed_milligas': '36899034',
#        'storage_size': '495'}},
#      {'kind': 'transaction',
#       'source': 'KT1UpbbE6FUgRczvMiemRj6x4kkqWRXueqTq',
#       'nonce': 10,
#       'amount': '97901000',
#       'destination': 'KT1GosH9zvtJwPFwGpwMbznmxxPwUZtu2B5B',
#       'parameters': {'entrypoint': 'receive_slice_from_burrow',
#        'value': {'prim': 'Pair',
#         'args': [{'bytes': '0000a26828841890d3f3a2a1d4083839c7a882fe0501'},
#          {'int': '6'}]}},
#       'result': {'status': 'applied',
#        'storage': {'prim': 'Pair',
#         'args': [{'int': '10'},
#          {'prim': 'Pair',
#           'args': [{'int': '11'},
#            {'prim': 'Left',
#             'args': [[[{'prim': 'Pair',
#                 'args': [{'int': '12'},
#                  {'prim': 'Pair',
#                   'args': [{'prim': 'Pair',
#                     'args': [{'prim': 'Pair',
#                       'args': [{'int': '100001'}, {'int': '126683'}]},
#                      {'prim': 'Pair',
#                       'args': [{'prim': 'Pair',
#                         'args': [{'int': '126655000000'},
#                          {'int': '100001000000'}]},
#                        {'int': '1879'}]}]},
#                    {'int': '100001'}]}]},
#                {'prim': 'Pair',
#                 'args': [{'bytes': '01a3e8b740667b08cb9f59573f6d27ce463aaeef1e00'},
#                  {'bytes': '01a16e75a833f6af685a3e052059cf7a3b8ae302a700'}]},
#                {'int': '13'},
#                {'int': '14'}],
#               {'prim': 'Pair',
#                'args': [{'prim': 'Some', 'args': [{'int': '100000000'}]},
#                 {'prim': 'Pair',
#                  'args': [{'prim': 'Pair',
#                    'args': [{'prim': 'Pair',
#                      'args': [{'prim': 'Pair',
#                        'args': [{'int': '2030'}, {'int': '15'}]},
#                       {'int': '16'}]},
#                     {'prim': 'Pair',
#                      'args': [{'prim': 'Some',
#                        'args': [{'prim': 'Pair',
#                          'args': [{'int': '2013'}, {'int': '2013'}]}]},
#                       {'prim': 'Some',
#                        'args': [{'prim': 'Pair',
#                          'args': [{'int': '2026'},
#                           {'prim': 'Right',
#                            'args': [{'prim': 'Pair',
#                              'args': [{'int': '1000000330829'},
#                               {'int': '1626076745'}]}]}]}]}]}]},
#                   {'int': '1'}]}]},
#               [{'prim': 'Pair',
#                 'args': [{'prim': 'Pair',
#                   'args': [{'int': '18446754502155676277'},
#                    {'int': '43699089742'}]},
#                  {'prim': 'Pair',
#                   'args': [{'int': '3888291585'}, {'int': '1235555'}]}]},
#                {'prim': 'Pair',
#                 'args': [{'int': '18446744624737676076'},
#                  {'int': '100000000'}]},
#                {'int': '1626076749'},
#                {'int': '43671034486'}],
#               {'prim': 'Pair',
#                'args': [{'int': '100000000'},
#                 {'int': '18446750191961542850'}]},
#               {'int': '2067214388118289116594'}]]}]}]},
#        'big_map_diff': [],
#        'balance_updates': [{'kind': 'contract',
#          'contract': 'KT1UpbbE6FUgRczvMiemRj6x4kkqWRXueqTq',
#          'change': '-97901000',
#          'origin': 'block'},
#         {'kind': 'contract',
#          'contract': 'KT1GosH9zvtJwPFwGpwMbznmxxPwUZtu2B5B',
#          'change': '97901000',
#          'origin': 'block'}],
#        'consumed_gas': '40249',
#        'consumed_milligas': '40248445',
#        'storage_size': '673441',
#        'lazy_storage_diff': [{'kind': 'big_map',
#          'id': '16',
#          'diff': {'action': 'update', 'updates': []}},
#         {'kind': 'big_map',
#          'id': '15',
#          'diff': {'action': 'update', 'updates': []}},
#         {'kind': 'big_map',
#          'id': '14',
#          'diff': {'action': 'update', 'updates': []}},
#         {'kind': 'big_map',
#          'id': '13',
#          'diff': {'action': 'update', 'updates': []}},
#         {'kind': 'big_map',
#          'id': '12',
#          'diff': {'action': 'update', 'updates': []}},
#         {'kind': 'big_map',
#          'id': '11',
#          'diff': {'action': 'update', 'updates': []}},
#         {'kind': 'big_map',
#          'id': '10',
#          'diff': {'action': 'update', 'updates': []}}]}},
#      {'kind': 'transaction',
#       'source': 'KT1GosH9zvtJwPFwGpwMbznmxxPwUZtu2B5B',
#       'nonce': 0,
#       'amount': '0',
#       'destination': 'KT1PJLgWy9z3nFQEhSciR379ng3wRRnQyuKQ',
#       'parameters': {'entrypoint': 'getPrice',
#        'value': {'bytes': '015a3b2eeae8d94760c662a22fc67e08cf4a3afa3f00726563656976655f7072696365'}},
#       'result': {'status': 'applied',
#        'storage': {'prim': 'Pair',
#         'args': [{'bytes': '0000a26828841890d3f3a2a1d4083839c7a882fe0501'},
#          {'int': '100000000'}]},
#        'consumed_gas': '35993',
#        'consumed_milligas': '35992201',
#        'storage_size': '225'}},
#      {'kind': 'transaction',
#       'source': 'KT1PJLgWy9z3nFQEhSciR379ng3wRRnQyuKQ',
#       'nonce': 11,
#       'amount': '0',
#       'destination': 'KT1GosH9zvtJwPFwGpwMbznmxxPwUZtu2B5B',
#       'parameters': {'entrypoint': 'receive_price',
#        'value': {'int': '100000000'}},
#       'result': {'status': 'applied',
#        'storage': {'prim': 'Pair',
#         'args': [{'int': '10'},
#          {'prim': 'Pair',
#           'args': [{'int': '11'},
#            {'prim': 'Left',
#             'args': [[[{'prim': 'Pair',
#                 'args': [{'int': '12'},
#                  {'prim': 'Pair',
#                   'args': [{'prim': 'Pair',
#                     'args': [{'prim': 'Pair',
#                       'args': [{'int': '100001'}, {'int': '126683'}]},
#                      {'prim': 'Pair',
#                       'args': [{'prim': 'Pair',
#                         'args': [{'int': '126655000000'},
#                          {'int': '100001000000'}]},
#                        {'int': '1879'}]}]},
#                    {'int': '100001'}]}]},
#                {'prim': 'Pair',
#                 'args': [{'bytes': '01a3e8b740667b08cb9f59573f6d27ce463aaeef1e00'},
#                  {'bytes': '01a16e75a833f6af685a3e052059cf7a3b8ae302a700'}]},
#                {'int': '13'},
#                {'int': '14'}],
#               {'prim': 'Pair',
#                'args': [{'prim': 'Some', 'args': [{'int': '100000000'}]},
#                 {'prim': 'Pair',
#                  'args': [{'prim': 'Pair',
#                    'args': [{'prim': 'Pair',
#                      'args': [{'prim': 'Pair',
#                        'args': [{'int': '2030'}, {'int': '15'}]},
#                       {'int': '16'}]},
#                     {'prim': 'Pair',
#                      'args': [{'prim': 'Some',
#                        'args': [{'prim': 'Pair',
#                          'args': [{'int': '2013'}, {'int': '2013'}]}]},
#                       {'prim': 'Some',
#                        'args': [{'prim': 'Pair',
#                          'args': [{'int': '2026'},
#                           {'prim': 'Right',
#                            'args': [{'prim': 'Pair',
#                              'args': [{'int': '1000000330829'},
#                               {'int': '1626076745'}]}]}]}]}]}]},
#                   {'int': '1'}]}]},
#               [{'prim': 'Pair',
#                 'args': [{'prim': 'Pair',
#                   'args': [{'int': '18446754502155676277'},
#                    {'int': '43699089742'}]},
#                  {'prim': 'Pair',
#                   'args': [{'int': '3888291585'}, {'int': '1235555'}]}]},
#                {'prim': 'Pair',
#                 'args': [{'int': '18446744624737676076'},
#                  {'int': '100000000'}]},
#                {'int': '1626076749'},
#                {'int': '43671034486'}],
#               {'prim': 'Pair',
#                'args': [{'int': '100000000'},
#                 {'int': '18446750191961542850'}]},
#               {'int': '2067214388118289116594'}]]}]}]},
#        'big_map_diff': [],
#        'consumed_gas': '39732',
#        'consumed_milligas': '39731678',
#        'storage_size': '673441',
#        'lazy_storage_diff': [{'kind': 'big_map',
#          'id': '16',
#          'diff': {'action': 'update', 'updates': []}},
#         {'kind': 'big_map',
#          'id': '15',
#          'diff': {'action': 'update', 'updates': []}},
#         {'kind': 'big_map',
#          'id': '14',
#          'diff': {'action': 'update', 'updates': []}},
#         {'kind': 'big_map',
#          'id': '13',
#          'diff': {'action': 'update', 'updates': []}},
#         {'kind': 'big_map',
#          'id': '12',
#          'diff': {'action': 'update', 'updates': []}},
#         {'kind': 'big_map',
#          'id': '11',
#          'diff': {'action': 'update', 'updates': []}},
#         {'kind': 'big_map',
#          'id': '10',
#          'diff': {'action': 'update', 'updates': []}}]}}]}}],
#  'signature': 'sigWhmWwvhkiYtWma5PT1FYLq5CWa3CLpn7Eh3y22xCt7zC4LADnRo96UCFXUoJjan2wm1hW6fbDKEAXoWq8DuHJWHmK9jQ9'}

# %%
# Out:
# 2026

# %%
# TODO:
# get auction id of current auction when placing bid
# add logic for reducing total auction time in e2e src patch
# Touch slices and reclaim bid

# TODO: Get this programatically above
current_auctions_ptr = 2013

# %%
def avl_storage(ptr):
    return checker.storage["deployment_state"]["sealed"]["liquidation_auctions"]["avl_storage"]["mem"][ptr]()

# %%
auction_slices = []






avl_storage(avl_storage(current_auctions_ptr)["root"][0])
# Out:
# {'branch': {'left': 101,
#   'left_height': 6,
#   'left_tez': 2839129000,
#   'parent': 2013,
#   'right': 165,
#   'right_height': 7,
#   'right_tez': 3734336000}}

# %%
def auction_avl_leaves(avl_ptr):
    node = avl_storage(avl_ptr)
    node_type = list(node.keys())[0]
    
    if node_type == "root":
        next_node, _ = node["root"]
        # Tree is empty
        if next_node is None:
            return []
        else:
            for ptr, leaf_node in auction_avl_leaves(next_node):
                yield ptr, leaf_node
    elif node_type == "leaf":
        yield avl_ptr, node
    else:
        # We are in a branch
        # Traverse left side first
        for ptr, leaf_node in auction_avl_leaves(node["branch"]["left"]):
            yield ptr, leaf_node        
        # Then the right side
        for ptr, leaf_node in auction_avl_leaves(node["branch"]["right"]):
            yield ptr, leaf_node

# %%
auctioned_slices = set([])
for leaf_ptr, leaf in auction_leaves(current_auctions_ptr):
    # Double check that we are only working with leaf ptrs
    assert "leaf" in leaf
    auctioned_slices.add(leaf_ptr)

# %%
# Note: gas exhausted when calling with all slices
# FIXME: What is the current max length of list we can pass here without exceeding
# the gas limit?
to_touch = list(auctioned_slices)

# %%
touched = []
for i in range(len(to_touch)):
    slice_ptr = to_touch[i]
    if i in touched:
        continue
    call_endpoint(checker, "touch_liquidation_slices", [slice_ptr])
# Out:
# Calling tz1aSkwEot3L2kmUvcoxzjMomb9mvBNuzFK6 / touch_liquidation_slices with [132]
# Calling tz1aSkwEot3L2kmUvcoxzjMomb9mvBNuzFK6 / touch_liquidation_slices with [136]
# Calling tz1aSkwEot3L2kmUvcoxzjMomb9mvBNuzFK6 / touch_liquidation_slices with [140]
# Calling tz1aSkwEot3L2kmUvcoxzjMomb9mvBNuzFK6 / touch_liquidation_slices with [144]
# Calling tz1aSkwEot3L2kmUvcoxzjMomb9mvBNuzFK6 / touch_liquidation_slices with [148]
# Calling tz1aSkwEot3L2kmUvcoxzjMomb9mvBNuzFK6 / touch_liquidation_slices with [152]
# Calling tz1aSkwEot3L2kmUvcoxzjMomb9mvBNuzFK6 / touch_liquidation_slices with [156]
# Calling tz1aSkwEot3L2kmUvcoxzjMomb9mvBNuzFK6 / touch_liquidation_slices with [160]
# Calling tz1aSkwEot3L2kmUvcoxzjMomb9mvBNuzFK6 / touch_liquidation_slices with [164]
# Calling tz1aSkwEot3L2kmUvcoxzjMomb9mvBNuzFK6 / touch_liquidation_slices with [168]
# Calling tz1aSkwEot3L2kmUvcoxzjMomb9mvBNuzFK6 / touch_liquidation_slices with [172]
# Calling tz1aSkwEot3L2kmUvcoxzjMomb9mvBNuzFK6 / touch_liquidation_slices with [176]
# Calling tz1aSkwEot3L2kmUvcoxzjMomb9mvBNuzFK6 / touch_liquidation_slices with [180]
# Calling tz1aSkwEot3L2kmUvcoxzjMomb9mvBNuzFK6 / touch_liquidation_slices with [184]
# Calling tz1aSkwEot3L2kmUvcoxzjMomb9mvBNuzFK6 / touch_liquidation_slices with [188]
# Calling tz1aSkwEot3L2kmUvcoxzjMomb9mvBNuzFK6 / touch_liquidation_slices with [192]
# Calling tz1aSkwEot3L2kmUvcoxzjMomb9mvBNuzFK6 / touch_liquidation_slices with [196]
# Calling tz1aSkwEot3L2kmUvcoxzjMomb9mvBNuzFK6 / touch_liquidation_slices with [200]
# Calling tz1aSkwEot3L2kmUvcoxzjMomb9mvBNuzFK6 / touch_liquidation_slices with [202]
# Calling tz1aSkwEot3L2kmUvcoxzjMomb9mvBNuzFK6 / touch_liquidation_slices with [204]
# Calling tz1aSkwEot3L2kmUvcoxzjMomb9mvBNuzFK6 / touch_liquidation_slices with [206]
# Calling tz1aSkwEot3L2kmUvcoxzjMomb9mvBNuzFK6 / touch_liquidation_slices with [82]
# Calling tz1aSkwEot3L2kmUvcoxzjMomb9mvBNuzFK6 / touch_liquidation_slices with [86]
# Calling tz1aSkwEot3L2kmUvcoxzjMomb9mvBNuzFK6 / touch_liquidation_slices with [90]
# Calling tz1aSkwEot3L2kmUvcoxzjMomb9mvBNuzFK6 / touch_liquidation_slices with [94]
# Calling tz1aSkwEot3L2kmUvcoxzjMomb9mvBNuzFK6 / touch_liquidation_slices with [96]
# Calling tz1aSkwEot3L2kmUvcoxzjMomb9mvBNuzFK6 / touch_liquidation_slices with [100]
# Calling tz1aSkwEot3L2kmUvcoxzjMomb9mvBNuzFK6 / touch_liquidation_slices with [104]
# Calling tz1aSkwEot3L2kmUvcoxzjMomb9mvBNuzFK6 / touch_liquidation_slices with [108]
# Calling tz1aSkwEot3L2kmUvcoxzjMomb9mvBNuzFK6 / touch_liquidation_slices with [112]
# Calling tz1aSkwEot3L2kmUvcoxzjMomb9mvBNuzFK6 / touch_liquidation_slices with [116]
# Calling tz1aSkwEot3L2kmUvcoxzjMomb9mvBNuzFK6 / touch_liquidation_slices with [120]
# Calling tz1aSkwEot3L2kmUvcoxzjMomb9mvBNuzFK6 / touch_liquidation_slices with [124]

# %%
print(avl_storage(current_auctions_ptr)["root"][0])
# Out:
# 128

# %%
call_endpoint(checker, "touch_liquidation_slices", [128])
avl_storage(current_auctions_ptr)["root"]
# Out:
# Calling tz1aSkwEot3L2kmUvcoxzjMomb9mvBNuzFK6 / touch_liquidation_slices with [128]
# (None,
#  {'older_auction': None,
#   'sold_tez': 10000000000,
#   'winning_bid': {'address': 'tz1aSkwEot3L2kmUvcoxzjMomb9mvBNuzFK6',
#    'kit': 30066325422},
#   'younger_auction': None})

# %%
call_endpoint(checker, "liquidation_auction_claim_win", current_auctions_ptr)
# Out:
# Calling tz1aSkwEot3L2kmUvcoxzjMomb9mvBNuzFK6 / liquidation_auction_claim_win with 2013
# {'protocol': 'PsFLorenaUUuikDWvMDr6fGBRG8kt3e3D3fHoXK1j1BFRxeSH4i',
#  'chain_id': 'NetXfpUfwJdBox9',
#  'hash': 'opFGqPYoJhuE254R8jbZZYZEPqMzuyEt5ZNjtaJdEbjmrwizGP3',
#  'branch': 'BL59kL1r5y7RFnhZqx4c7vLAWYSa5QJvjswed7pzCw9PMb6RuPT',
#  'contents': [{'kind': 'transaction',
#    'source': 'tz1aSkwEot3L2kmUvcoxzjMomb9mvBNuzFK6',
#    'fee': '5325',
#    'counter': '6202',
#    'gas_limit': '50236',
#    'storage_limit': '100',
#    'amount': '0',
#    'destination': 'KT1EbVVPit28YGES6pcihRJWJrLtxQrycbbS',
#    'parameters': {'entrypoint': 'liquidation_auction_claim_win',
#     'value': {'int': '2013'}},
#    'metadata': {'balance_updates': [{'kind': 'contract',
#       'contract': 'tz1aSkwEot3L2kmUvcoxzjMomb9mvBNuzFK6',
#       'change': '-5325',
#       'origin': 'block'},
#      {'kind': 'freezer',
#       'category': 'fees',
#       'delegate': 'tz1YPSCGWXwBdTncK2aCctSZAXWvGsGwVJqU',
#       'cycle': 785,
#       'change': '5325',
#       'origin': 'block'}],
#     'operation_result': {'status': 'applied',
#      'storage': {'prim': 'Pair',
#       'args': [{'int': '17'},
#        {'prim': 'Pair',
#         'args': [{'int': '18'},
#          {'prim': 'Left',
#           'args': [[[{'prim': 'Pair',
#               'args': [{'int': '19'},
#                {'prim': 'Pair',
#                 'args': [{'prim': 'Pair',
#                   'args': [{'prim': 'Pair',
#                     'args': [{'int': '100001'}, {'int': '142172'}]},
#                    {'prim': 'Pair',
#                     'args': [{'prim': 'Pair',
#                       'args': [{'int': '119714000000'},
#                        {'int': '100001000000'}]},
#                      {'int': '4107'}]}]},
#                  {'int': '100001'}]}]},
#              {'prim': 'Pair',
#               'args': [{'bytes': '010a3fd04d9ba1ca4a1d2a56070e7c0febb12b817900'},
#                {'bytes': '01baacbb1f62106351dba5e107d3a1ba19f6c5c9e900'}]},
#              {'int': '20'},
#              {'int': '21'}],
#             {'prim': 'Pair',
#              'args': [{'prim': 'Some', 'args': [{'int': '1000000'}]},
#               {'prim': 'Pair',
#                'args': [{'prim': 'Pair',
#                  'args': [{'prim': 'Pair',
#                    'args': [{'prim': 'Pair',
#                      'args': [{'int': '2030'}, {'int': '22'}]},
#                     {'int': '23'}]},
#                   {'prim': 'Pair',
#                    'args': [{'prim': 'None'},
#                     {'prim': 'Some',
#                      'args': [{'prim': 'Pair',
#                        'args': [{'int': '2026'},
#                         {'prim': 'Right',
#                          'args': [{'prim': 'Pair',
#                            'args': [{'int': '10000000947'},
#                             {'int': '1625835972'}]}]}]}]}]}]},
#                 {'int': '1'}]}]},
#             [{'prim': 'Pair',
#               'args': [{'prim': 'Pair',
#                 'args': [{'int': '18446762574850417689'},
#                  {'int': '17233933794'}]},
#                {'prim': 'Pair',
#                 'args': [{'int': '5633389467'}, {'int': '1235555'}]}]},
#              {'prim': 'Pair',
#               'args': [{'int': '18446747789190024466'}, {'int': '1000000'}]},
#              {'int': '1625839684'},
#              {'int': '17156581747'}],
#             {'prim': 'Pair',
#              'args': [{'int': '1000000'}, {'int': '18446758218932352327'}]},
#             {'int': '22078519659461348563'}]]}]}]},
#      'big_map_diff': [{'action': 'update',
#        'big_map': '22',
#        'key_hash': 'exprvN6aLe6PQm3EdVFQRNrD6CvLTDMAqRUBJreFcyNjGbLn2FcVWx',
#        'key': {'int': '2013'}}],
#      'consumed_gas': '48709',
#      'consumed_milligas': '48708940',
#      'storage_size': '645789',
#      'lazy_storage_diff': [{'kind': 'big_map',
#        'id': '23',
#        'diff': {'action': 'update', 'updates': []}},
#       {'kind': 'big_map',
#        'id': '22',
#        'diff': {'action': 'update',
#         'updates': [{'key_hash': 'exprvN6aLe6PQm3EdVFQRNrD6CvLTDMAqRUBJreFcyNjGbLn2FcVWx',
#           'key': {'int': '2013'}}]}},
#       {'kind': 'big_map',
#        'id': '21',
#        'diff': {'action': 'update', 'updates': []}},
#       {'kind': 'big_map',
#        'id': '20',
#        'diff': {'action': 'update', 'updates': []}},
#       {'kind': 'big_map',
#        'id': '19',
#        'diff': {'action': 'update', 'updates': []}},
#       {'kind': 'big_map',
#        'id': '18',
#        'diff': {'action': 'update', 'updates': []}},
#       {'kind': 'big_map',
#        'id': '17',
#        'diff': {'action': 'update', 'updates': []}}]},
#     'internal_operation_results': [{'kind': 'transaction',
#       'source': 'KT1EbVVPit28YGES6pcihRJWJrLtxQrycbbS',
#       'nonce': 0,
#       'amount': '10000000000',
#       'destination': 'tz1aSkwEot3L2kmUvcoxzjMomb9mvBNuzFK6',
#       'result': {'status': 'applied',
#        'balance_updates': [{'kind': 'contract',
#          'contract': 'KT1EbVVPit28YGES6pcihRJWJrLtxQrycbbS',
#          'change': '-10000000000',
#          'origin': 'block'},
#         {'kind': 'contract',
#          'contract': 'tz1aSkwEot3L2kmUvcoxzjMomb9mvBNuzFK6',
#          'change': '10000000000',
#          'origin': 'block'}],
#        'consumed_gas': '1427',
#        'consumed_milligas': '1427000'}}]}}],
#  'signature': 'sigZz7YNDMmmoGa44LRYccf9FAN98ezcgtEVxRja3PAdGeASguPaeD3Vm2A21fGxBxfJxYN4YSt1A2vbT39DGckQrhe8wmib'}
